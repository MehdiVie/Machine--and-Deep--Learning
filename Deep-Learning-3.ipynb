# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
import matplotlib.pyplot as plt

# %%
# y = x^2 + 5*x + 3

x = np.arange(-80 , 80 , 0.5)
y= x**2 + 5*x + 3

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(x, y, test_size=0.2)

# %%
model_2 = keras.Sequential()
model_2.add(keras.layers.Dense(units=256, activation="relu", input_shape=(1,)))
model_2.add(keras.layers.Dense(units=256 , activation="relu"))
model_2.add(keras.layers.Dense(units=256 , activation="relu"))
model_2.add(keras.layers.Dense(units=256 , activation="relu"))
model_2.add(keras.layers.Dense(units=1))

# %%
optimizer= keras.optimizers.RMSprop(learning_rate=0.0001)
loss = keras.losses.MeanSquaredError
metric = [keras.metrics.RootMeanSquaredError()]

model_2.compile(optimizer=optimizer, loss=loss , metrics=metric)

# %%
early_stop = keras.callbacks.EarlyStopping(monitor="val_loss", patience=200 , restore_best_weights=True)

# %%
hist_2 = model_2.fit(X_train, y_train, epochs=1000, callbacks=[early_stop], batch_size=128 , validation_data=(X_test, y_test))
# Out:
# Epoch 1/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 507669.6562 - root_mean_squared_error: 712.4105 - val_loss: 519669.8750 - val_root_mean_squared_error: 720.8813
# Epoch 2/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 511646.3125 - root_mean_squared_error: 715.1750 - val_loss: 518563.1250 - val_root_mean_squared_error: 720.1133
# Epoch 3/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 525500.5625 - root_mean_squared_error: 724.8961 - val_loss: 518206.6250 - val_root_mean_squared_error: 719.8657
# Epoch 4/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 522202.4375 - root_mean_squared_error: 722.6357 - val_loss: 518102.0312 - val_root_mean_squared_error: 719.7930
# Epoch 5/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 518732.4375 - root_mean_squared_error: 720.2300 - val_loss: 519301.7500 - val_root_mean_squared_error: 720.6259
# Epoch 6/1000
# ...

# %%
plt.plot(hist_2.history["loss"] , color="red")
plt.plot(hist_2.history["val_loss"] , color="blue")
plt.show()

# %%
early_stop = keras.callbacks.EarlyStopping(monitor="val_loss", patience=300 , restore_best_weights=True)
hist_3 = model_2.fit(X_train, y_train, epochs=1000, callbacks=[early_stop], batch_size=128 , validation_data=(X_test, y_test))
# Out:
# Epoch 1/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 402239.7500 - root_mean_squared_error: 634.2176 - val_loss: 394719.8750 - val_root_mean_squared_error: 628.2673
# Epoch 2/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 389879.7500 - root_mean_squared_error: 623.6520 - val_loss: 395605.7500 - val_root_mean_squared_error: 628.9720
# Epoch 3/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 397741.5625 - root_mean_squared_error: 630.5400 - val_loss: 398107.8125 - val_root_mean_squared_error: 630.9578
# Epoch 4/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 398967.7812 - root_mean_squared_error: 631.5571 - val_loss: 396900.0312 - val_root_mean_squared_error: 630.0000
# Epoch 5/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 403725.0312 - root_mean_squared_error: 635.3921 - val_loss: 398654.0938 - val_root_mean_squared_error: 631.3906
# Epoch 6/1000
# ...

# %%
plt.plot(hist_3.history["loss"] , color="red")
plt.plot(hist_3.history["val_loss"] , color="blue")
plt.show()
